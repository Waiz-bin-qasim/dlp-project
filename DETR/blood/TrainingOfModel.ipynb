# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 713.3 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.5/756.5 kB 5.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="n1HHUV12gq6UcE9Eue27")
project = rf.workspace("blood-detection-model").project("blood-detection-po83l")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 890.9 kB/s eta 0:00:000:00:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.7 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 31.1 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
# ...

# %%
from ultralytics import RTDETR

model = RTDETR('rtdetr-l.pt')
model.info()
results = model.train(data='/kaggle/input/ascascas/data.yaml', epochs=50, imgsz=640)
results = model.export(format='onnx')
# Out:
# rt-detr-l summary: 673 layers, 32970476 parameters, 0 gradients, 108.3 GFLOPs
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:1024"

# %%
# !zip -r file.zip /kaggle/working/runs/detect/train2
# Out:
#   adding: kaggle/working/runs/detect/train2/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/train_batch6482.jpg (deflated 7%)
#   adding: kaggle/working/runs/detect/train2/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/weights/last.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train2/events.out.tfevents.1715203218.6e5dd70a7ef3.34.1 (deflated 94%)
#   adding: kaggle/working/runs/detect/train2/train_batch1.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train2/train_batch2.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/train2/train_batch0.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/train2/labels.jpg (deflated 27%)
#   adding: kaggle/working/runs/detect/train2/labels_correlogram.jpg (deflated 30%)
#   adding: kaggle/working/runs/detect/train2/args.yaml (deflated 52%)
#   adding: kaggle/working/runs/detect/train2/train_batch6481.jpg (deflated 5%)
# ...

# %%
# !ls
# Out:
# Blood-detection-2  file.zip  rtdetr-l.pt  runs	wandb  yolov8n.pt
