# %%
# !pip install roboflow
# Out:
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/5d/d5/666eaa3f370ba99bf8d31daadc1c739f0874da6bb155d781fcf34e21e4a0/roboflow-1.1.11-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.5 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for opencv-python-headless==4.8.0.74 from https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for supervision from https://files.pythonhosted.org/packages/c0/59/6bc863f530c0ba5da4c565fd40f17b2b333c2ab28b783202937293ae494a/supervision-0.16.0-py3-none-any.whl.metadata
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="n1HHUV12gq6UcE9Eue27")
project = rf.workspace("blood-detection-model").project("blood-detection-po83l")
dataset = project.version(2).download("yolov8")
# Out:
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Blood-detection-2 in yolov8:: 100%|██████████| 6467/6467 [00:01<00:00, 5658.69it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/c6/65/efd22282862c97fc817630faefa07d4990806ca31e51a7a674742f7f5651/ultralytics-8.0.221-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.6/646.6 kB 20.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='/kaggle/input/blood-yaml/data.yaml', epochs=100)
print(results)
results = model.val()
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.0.0 CPU (Intel Xeon 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.9 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: export success ✅ 0.8s, saved as 'runs/detect/train3/weights/best.onnx' (11.7 MB)
#
# Export complete (2.3s)
# Results saved to /kaggle/working/runs/detect/train3/weights
# Predict:         yolo predict task=detect model=runs/detect/train3/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train3/weights/best.onnx imgsz=640 data=/kaggle/input/blood-yaml/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train3/weights/best.onnx'

# %%
# !zip -r blood.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train32/ (stored 0%)
#   adding: kaggle/working/runs/detect/train32/val_batch1_pred.jpg (deflated 10%)
#   adding: kaggle/working/runs/detect/train32/val_batch2_labels.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/train32/PR_curve.png (deflated 13%)
#   adding: kaggle/working/runs/detect/train32/val_batch0_pred.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train32/val_batch1_labels.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train32/P_curve.png (deflated 12%)
#   adding: kaggle/working/runs/detect/train32/confusion_matrix.png (deflated 33%)
#   adding: kaggle/working/runs/detect/train32/R_curve.png (deflated 12%)
#   adding: kaggle/working/runs/detect/train32/F1_curve.png (deflated 12%)
#   adding: kaggle/working/runs/detect/train32/val_batch2_pred.jpg (deflated 12%)
# ...

# %%
from IPython.display import FileLink
FileLink(r'blood.zip')
# Out:
# /kaggle/working/blood.zip
